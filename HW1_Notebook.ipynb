# %% [markdown]
# # Run this Notebook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DeepRLCourse/Homework-1-Questions/blob/main/HW1_Notebook.ipynb)
# [![Open in Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/DeepRLCourse/Homework-1-Questions/blob/main/HW1_Notebook.ipynb)
#
# # HW1: Introduction to RL
# > - Full Name: **Arshia Tahayori**
# > - Student ID: **403131017**
#
#
# This notebook is designed to provide hands-on experience with RL modeling, algorithm implementation, and performance evaluation. Students will explore RL concepts through predefined environments and custom-designed settings.
#
# Follow the instructions in each section to complete the homework.

# %% [markdown]
# ## Setup Instructions
# Seting up RL dependecies for first time may be challenging. Some  torch or gymnasium (Sklearn lib in SL world!) environments need additional set up on your system. If you encountered error and failure after hours of search and try, feel free to be in contact with TA's.  Run the following commands to install dependencies before starting the notebook:

# %%
# !apt-get install x11-utils > /dev/null 2>&1
# !pip install pyglet > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !apt-get install xvfb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.14).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %%
# !pip install pyvirtualdisplay > /dev/null 2>&1
# !pip install swig
# !pip install stable-baselines3 "gymnasium[all]" pygame matplotlib numpy pandas
# Out:
# Collecting swig
#   Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 17.3 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.3.0
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (2.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: gymnasium[all] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (4.13.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.10.2)
# Collecting box2d-py==2.3.5 (from gymnasium[all])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (4.3.0)
# Collecting mujoco-py<2.2,>=2.1 (from gymnasium[all])
#   Downloading mujoco_py-2.1.2.14-py3-none-any.whl.metadata (669 bytes)
# Collecting cython<3 (from gymnasium[all])
#   Downloading Cython-0.29.37-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (3.1 kB)
# Collecting mujoco>=2.1.5 (from gymnasium[all])
#   Downloading mujoco-3.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (2.37.0)
# Requirement already satisfied: jax>=0.4.16 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.5.2)
# Requirement already satisfied: jaxlib>=0.4.16 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.5.1)
# Requirement already satisfied: flax>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.10.5)
# Requirement already satisfied: opencv-python>=3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (4.11.0.86)
# Requirement already satisfied: moviepy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (1.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.11.10)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.1.73)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (13.9.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.1.9)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.16->gymnasium[all]) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.16->gymnasium[all]) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.16->gymnasium[all]) (1.14.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (0.1.11)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (0.6.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[all]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[all]) (1.12.2)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[all])
#   Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[all]) (3.1.9)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.11/dist-packages (from mujoco-py<2.2,>=2.1->gymnasium[all]) (1.17.1)
# Collecting fasteners~=0.15 (from mujoco-py<2.2,>=2.1->gymnasium[all])
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.10->mujoco-py<2.2,>=2.1->gymnasium[all]) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (2.18.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[all]) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[all]) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.5.0->gymnasium[all]) (0.1.89)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (5.29.4)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (4.12.2)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (3.20.1)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax>=0.5.0->gymnasium[all]) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.5.0->gymnasium[all]) (0.1.2)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 14.3 MB/s eta 0:00:00
# Downloading Cython-0.29.37-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 39.9 MB/s eta 0:00:00
# Downloading mujoco-3.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 93.1 MB/s eta 0:00:00
# Downloading mujoco_py-2.1.2.14-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 75.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.4 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 18.9 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=2379445 sha256=d910885d98e46e897d9e05188d4ed8782c3cfa557aafe5291566f00168ea1825
#   Stored in directory: /root/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: glfw, box2d-py, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fasteners, cython, nvidia-cusparse-cu12, nvidia-cudnn-cu12, mujoco-py, nvidia-cusolver-cu12, mujoco, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.12
#     Uninstalling Cython-3.0.12:
#       Successfully uninstalled Cython-3.0.12
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed box2d-py-2.3.5 cython-0.29.37 fasteners-0.19 glfw-2.8.0 mujoco-3.3.1 mujoco-py-2.1.2.14 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable-baselines3-2.6.0

# %% [markdown]
# Hamid is CE student who loves learning about RL. He tried to use **Gymnasium** and **Stable-Baselines3** to solve games he played as a kid.
#
# He started to list the games which was provided in gymnasium library.

# %%
from gymnasium import envs

all_envs = envs.registry
env_ids = [env_spec  for env_spec in all_envs]
print("Gymnasium envs listed:",sorted(env_ids))
# Out:
# Gymnasium envs listed: ['Acrobot-v1', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Ant-v5', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'Blackjack-v1', 'CarRacing-v3', 'CartPole-v0', 'CartPole-v1', 'CliffWalking-v0', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'GymV21Environment-v0', 'GymV26Environment-v0', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'HalfCheetah-v5', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Hopper-v5', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'Humanoid-v5', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'HumanoidStandup-v5', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'InvertedDoublePendulum-v5', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedPendulum-v5', 'LunarLander-v3', 'LunarLanderContinuous-v3', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Pusher-v2', 'Pusher-v4', 'Pusher-v5', 'Reacher-v2', 'Reacher-v4', 'Reacher-v5', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Swimmer-v5', 'Taxi-v3', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Walker2d-v5', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0']

# %% [markdown]
# Then He selected Mountain Car Game to work with:

# %%
import gymnasium as gym
env = gym.make("MountainCar-v0", render_mode="rgb_array", goal_velocity=0.1)

print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))

print("Action Example: {}".format(env.action_space.sample()))
print("State Example: {}".format(env.observation_space.sample()))
# Out:
# Action Space Discrete(3)
# State Space Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Example: 1
# State Example: [0.5418356  0.06850658]

# %% [markdown]
# Hamid wanted to visualize the env for better understandig of gym envs. He had two options:
#
#
# 1.   rendering inside the colab
# 2.   rendering as video file

# %% [markdown]
# For ploting the game **inside** the colab he used **pyvirtualdisplay** package:

# %%
from pyvirtualdisplay import Display
import numpy as np
import matplotlib.pyplot as plt
from IPython import display as ipythondisplay

display = Display(visible=0, size=(400, 300))
display.start()

# %% [markdown]
# So He started modify the code to learn how action works and plot it. He selected action of
#
#  *`2: Accelerate to the right`*
#
# For every state of car.

# %%
env.reset()
prev_screen = env.render( )
plt.imshow(prev_screen)

for i in range(40):
  # action = env.action_space.sample()  # Random action
  action = 2 # Action Hamid modified to practice
  obs, reward,terminated, truncated, info = env.step(action)
  screen = env.render()

  plt.imshow(screen)
  ipythondisplay.clear_output(wait=True)
  ipythondisplay.display(plt.gcf())

  if terminated:
    break

ipythondisplay.clear_output(wait=True)
env.close()

# %% [markdown]
# But for saving game as **video** he defined a function (it's okay if you don't understand just try to run the code and see the output, then try to modify envs!):

# %%
import logging
from gymnasium.wrappers import RecordEpisodeStatistics, RecordVideo

training_period = 250  # record the agent's episode every 250
num_training_episodes = 1000  # total number of training episodes

env = gym.make("MountainCar-v0", render_mode="rgb_array")
env = RecordVideo(env, video_folder="MountainCar-v0-agent", name_prefix="training",
                  episode_trigger=lambda x: x % training_period == 0)
env = RecordEpisodeStatistics(env)

for episode_num in range(num_training_episodes):
    obs, info = env.reset()

    episode_over = False
    while not episode_over:
        action = env.action_space.sample()  # replace with actual agent
        obs, reward, terminated, truncated, info = env.step(action)

        episode_over = terminated or truncated

    logging.info(f"episode-{episode_num}", info["episode"])
env.close()

# %% [markdown]
# The videos are in MountainCar-v0-agent folder of your colab folder.

# %% [markdown]
# But the car couldn't reach the goal state on top of the right hill. So he tried to implement RL algorithm for learning it

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments can bet set but Hamid set 1 env
vec_env = make_vec_env("MountainCar-v0", n_envs=1)

model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo_MountainCar")

del model # remove to demonstrate saving and loading
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 967      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 712          |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0008436474 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.000236    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000152    |
# |    value_loss           | 135          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 698          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0060305204 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0121      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.8         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000755    |
# |    value_loss           | 87.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008595003 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00156    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 83.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 5           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008767132 |
# |    clip_fraction        | 0.00967     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00308    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 68.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 656          |
# |    iterations           | 6            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0022150956 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000394    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.51         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000212    |
# |    value_loss           | 53.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 657         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010284133 |
# |    clip_fraction        | 0.00273     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0046     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.39        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000592   |
# |    value_loss           | 41.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 657         |
# |    iterations           | 8           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014246576 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.00504    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.03        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 30.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 651          |
# |    iterations           | 9            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0076198205 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.97        |
# |    explained_variance   | 0.00126      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.61         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 21           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 10           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0006560311 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | 0.00142      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.0005       |
# |    value_loss           | 13.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 11          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011359602 |
# |    clip_fraction        | 0.0132      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.000988   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.962       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00177    |
# |    value_loss           | 9.01        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 646        |
# |    iterations           | 12         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00539677 |
# |    clip_fraction        | 0.00469    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.000363  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.355      |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 0.000239   |
# |    value_loss           | 5.72       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 640          |
# |    iterations           | 13           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0054170126 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.000217     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.227        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 3.67         |
# ------------------------------------------

# %% [markdown]
# **Loading saved model**
#
# After training model using PPO and saving it, Hamid started to load the model with the name he saved in cell above:

# %%
model = PPO.load("ppo_MountainCar")

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    print(obs, rewards, dones, info)
    if dones[0]:
      break
# Out:
# [[-0.53863597 -0.00089396]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.53941715 -0.00078122]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5400798  -0.00066262]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.3961885e-01  4.6093378e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.400378e-01 -4.189618e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5393335   0.00070428]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.3951132e-01 -1.7775192e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.3956974e-01 -5.8453326e-05]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5385085   0.00106128]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5363354   0.00217307]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.53406686  0.00226857]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.53171974  0.00234707]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5293118   0.00240797]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.527861    0.00145081]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.2737820e-01  4.8278007e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.2786708e-01 -4.8887485e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.2832395e-01 -4.5686352e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52974534 -0.00142143]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5321207  -0.00237533]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5354321  -0.00331142]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5386548  -0.00322269]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54076463 -0.00210981]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54374576 -0.00298112]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54657584 -0.00283011]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5492338  -0.00265792]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5506996  -0.00146585]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.55196244 -0.00126281]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5540128  -0.00205034]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.55683535 -0.00282256]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.55840904 -0.00157369]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5597221  -0.00131309]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5607648 -0.0010427]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.56152934 -0.00076453]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.6200999e-01 -4.8066254e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.56120324  0.00080678]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.560115    0.00108822]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.55875343  0.00136154]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5581287   0.00062472]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.5824548e-01 -1.1677257e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.5810291e-01  1.4261028e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.558702   -0.00059907]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.56003827 -0.00133628]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5611018  -0.00106353]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.56188464 -0.00078285]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.6138098e-01  5.0366146e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.56059456  0.00078642]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5585312   0.00206332]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5562064   0.00232483]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5536374  0.002569 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5518434   0.00179399]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5498378   0.00200557]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5476357   0.00220216]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5462534   0.00138228]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54470134  0.00155206]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5429911   0.00171022]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54113555  0.00185558]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5391485   0.00198705]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5360449   0.00310363]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5338479   0.00219695]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5325741   0.00127381]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.3223300e-01  3.4111453e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.53282714 -0.00059414]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.333521e-01 -5.249323e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.53480387 -0.00145179]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.3517163e-01 -3.6777076e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5364526  -0.00128099]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.3663725e-01 -1.8461190e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5377241  -0.00108685]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.3770500e-01  1.9059647e-05]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5385802  -0.00087518]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54034305 -0.00176285]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5409804  -0.00063732]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-5.4148740e-01 -5.0702016e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5428603  -0.00137292]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5450888  -0.00222854]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5481563  -0.00306748]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.55103976 -0.00288346]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5537177  -0.00267788]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.55717   -0.0034523]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5613709  -0.00420094]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.56528914 -0.00391826]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.56989557 -0.00460639]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.57415587 -0.00426028]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5790384  -0.00488256]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5825071  -0.00346867]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5865362  -0.00402916]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.59109616 -0.00455993]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.59515333 -0.00405715]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5996779 -0.0045246]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.60363686 -0.00395895]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.60700125 -0.00336442]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6107467 -0.0037454]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6148459  -0.00409921]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.61826926 -0.00342338]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.61999214 -0.00172285]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.62200207 -0.00200994]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6242846  -0.00228259]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.62682354 -0.00253887]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6276005 -0.000777 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-6.276101e-01 -9.583239e-06]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6268522  0.0007579]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-6.2633222e-01  5.1998015e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6250539   0.00127834]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6230263   0.00202756]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.62126404  0.00176226]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.61977977  0.00148431]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.61858404  0.0011957 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.61768556  0.00089849]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-6.1709076e-01  5.9480703e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-6.1680388e-01  2.8683958e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-6.1682713e-01 -2.3195400e-05]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-6.1716014e-01 -3.3306316e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6178007  -0.00064053]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-6.177441e-01  5.661714e-05]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6159907   0.00175336]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6135533   0.00243746]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6104493   0.00310396]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6077013   0.00274799]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6053292   0.00237209]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6033503   0.00197894]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6017789   0.00157139]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5986265   0.00315238]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5939162   0.00471035]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.58768237  0.00623383]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.57997084  0.0077115 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5708386   0.00913228]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5623532   0.00848539]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5535778   0.00877539]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5455778   0.00799993]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5364132   0.00916466]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5271525   0.00926074]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.51886505  0.00828739]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5116132   0.00725189]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.50445116  0.00716202]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.49743265  0.00701849]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4906102   0.00682245]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4830348   0.00757544]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47676283  0.00627196]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.470841    0.00592184]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46631318  0.00452781]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4622129   0.00410028]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4595704   0.00264248]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4584052   0.00116522]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45772582  0.00067938]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45853728 -0.00081146]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.45983362 -0.00129633]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46160528 -0.00177166]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46283922 -0.00123393]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4635263  -0.00068711]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46466154 -0.00113522]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4672365  -0.00257495]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.46923214 -0.00199566]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.47263375 -0.0034016 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.4774161  -0.00478235]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.48354372 -0.00612761]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.490971  -0.0074273]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.49764264 -0.00667162]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.50450873 -0.0068661 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.51151794 -0.00700919]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5196177  -0.00809978]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.52774733 -0.00812964]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.53684586 -0.00909852]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.54484504 -0.0079992 ]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.553685   -0.00883996]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5622996  -0.00861462]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.56962466 -0.00732501]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.57660556 -0.00698091]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5841906  -0.00758504]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5903237 -0.0061331]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5969597  -0.00663599]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6040499  -0.00709022]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6095426  -0.00549268]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6153978  -0.00585522]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.62057316 -0.00517539]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6260315 -0.0054583]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6317336  -0.00570209]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6366388  -0.00490523]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6397124  -0.00307359]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6419326  -0.00222024]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6432839  -0.00135126]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6447567  -0.00147278]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-6.4534062e-01 -5.8397616e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.64603174 -0.00069108]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-6.4582509e-01  2.0666339e-04]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6447221   0.00110296]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6437306   0.00099152]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.64185745  0.00187313]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6381159   0.00374158]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6345322   0.00358367]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6311318   0.00340039]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.62593883  0.00519297]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6189903   0.00694852]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.61133605  0.00765423]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.6030314   0.00830469]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5941366   0.00889482]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.5847167   0.00941991]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.57584095  0.00887573]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.566575    0.00926594]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.55798763  0.00858737]] [-1.] [False] [{'TimeLimit.truncated': False}]
# [[-0.42339113  0.        ]] [-1.] [ True] [{'episode': {'r': -200.0, 'l': 200, 't': 68.933644}, 'TimeLimit.truncated': True, 'terminal_observation': array([-0.55014277,  0.00784483], dtype=float32)}]

# %% [markdown]
# # **Task 1: Solving Predefined Environments (45 points)**
# 1.1. Choose two environments from the list which are implemented by  other developers and communities and train RL agents using stable-baselines3. Don't forget to check workshop notebook.
#
# **Environments:**
# - [CartPole](https://gymnasium.farama.org/environments/classic_control/cart_pole/)
# - [FrozenLake](https://gymnasium.farama.org/environments/toy_text/frozen_lake/)
# - [Taxi](https://gymnasium.farama.org/environments/toy_text/taxi/)
# - Flappy Bird (Custom env which you can google it)

# %% [markdown]
# 📊 1.2. Algorithm Comparison:
#
#
#  Compare RL algorithms and results (at least two algorithms e.g., PPO, DQN) based on:
# - Total reward over time
# - Hyperparameters (check the docs)

# %% [markdown]
# Env1 implementation. [ place for your code ]

# %%
# TODO's:
# Import env 1
# Train env 1
# plot env1 total rewards on sepearate lines for each algorithm
# modify hyperparameters and plot reward curves

# %% [markdown]
# Env2 implementation. [ place for your code ]

# %%
# TODO's:
# Import env 2
# Train env 2
# plot env2 total rewards on sepearate lines for each algorithm
# modify hyperparameters and plot reward curves

# %% [markdown]
# Write a wrapper for changing reward function and plot the changes. (Bonus)

# %%
# Bonus TODO's: Your wrapper for reward function

# %% [markdown]
# # **Task 2: Creating Custom Environment (45 points)**
# In this question, you are required to model **a custom 4*4 gridworld problem** as Markov Decision Processes (MDPs). You must define the following components:
#
# <img src="data:image/png;base64,..." width="400"/>
#
# - **State Space ($ S $)**: The set of all possible states the agent can be in.
# - **Action Space ($ A $)**: The set of all possible actions the agent can take.
# - **Reward Function ($ R $)**: The reward the agent receives for taking an action in a given state.
# - **Transition Probability ($ P $)**: The probability of transitioning to a new state given the current state and action. If the environment is deterministic, this can be omitted.
#
# After defining the MDP components, implement problem using the **Gymnasium standard API**. Then, test the environments using various reinforcement learning algorithms (e.g., Q-Learning, DQN, PPO) and evaluate their performance.

# %%
# TODO: Defineing your custom env
class YourAwesomeEnvironment(gym.Env):
    def __init__(self) -> None:
        super().__init__()
        self.action_space = ...
        self.observation_space = ...

    def step(
        self, action: Any
    ) -> tuple[Any, SupportsFloat, bool, bool, dict[str, Any]]:
        return super().step(action)

    def reset(
        self, *, seed: int | None = None, options: dict[str, Any] | None = None
    ) -> tuple[Any, dict[str, Any]]:
        return super().reset(seed=seed, options=options)

    #Optional
    def render(self):
        return super().render()

    def close(self):
        return super().close()

# %%
# TODO: Training agent on your env

# %% [markdown]
# 📊 Algorithm Comparison
# Compare RL algorithms (e.g., PPO, DQN) based on:
# - Total reward over time
# - Sample efficiency
# - Hyperparameters

# %%
# TODO: Algorithm comparison code

# %% [markdown]
# # **Task 3: Pygame 🎮 Tutorial & Custom RL Environment (Bonus)**
#
# In this bonus task, you will implement a custom RL environment using Pygame and make it Gym-compatible for training an RL agent. Pygame is widely used for 2D game development and can be an excellent tool for creating custom RL environments. You will start by learning basic Pygame concepts (game loop, rendering, input handling), then implement a simple grid-based environment where an agent moves toward a goal while avoiding obstacles. Finally, you will train an RL agent using Stable-Baselines3 (SB3) to solve the environment. If you’re looking for inspiration, consider recreating the Chrome Dino game 🦖 as an RL environment which will be introduced at workshop or future TA sessions, but feel free to explore your own ideas!

# %% [markdown]
# ![preview.png](data:image/png;base64,...)
